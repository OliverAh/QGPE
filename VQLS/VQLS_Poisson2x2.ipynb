# %%
# Import the necessary libraries
import qiskit
from qiskit import *
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pylatexenc
from scipy.optimize import minimize
from qiskit.visualization import plot_histogram
import math
import cmath
import random
import copy
import time
from qiskit_aer import Aer

# %%
# Note that for the Poisson Problem, the right side is taken as a vector of constants after discretization where
# f = [1,1,1,1,1,1,1,1]^T with two additional boundary points (u(0) and u(1))
def create_b(circuit,qubits):
    for i in qubits:
        circuit.h(i)

def create_b_dagger(circuit, qubits):
    create_b(circuit,qubits)

# %%
ansatz_param = None

def create_ansatz(circuit, qubit_list,layers=3,not_final=True):
    param_idx = 0
    for k in range(layers):
        for i in range(len(qubit_list)):
            circuit.ry(ansatz_param[param_idx], qubit_list[i])
            param_idx += 1
        if k == layers-1:
            continue
        if k % 2 == 0:
            if not_final:
                circuit.cz(1,2)
            else:
                circuit.cz(0,1)
        elif k % 2 == 1:
            if not_final:
                circuit.cz(2,1)
            else:
                circuit.cz(1,0)
        else:
            pass

# %%
c = [2.0, -1.0, -0.5, -0.5]

I = np.eye(2)
X = np.array([[0,1],[1,0]])
Y = np.array([[0,-1j],[1j,0]])
Z = np.array([[1,0],[0,-1]])

a1 = c[0] * np.eye(4)
a2 = c[1] * np.kron(I,X)
a3 = c[2] * np.kron(X,X)
a4 = c[3] * np.kron(Y,Y)

A = a1 + a2 + a3 + a4
b = np.ones(4) / np.sqrt(4)

sol = np.linalg.solve(A,b)
print(sol)
# Out:
# [1. +0.j 1.5+0.j 1.5+0.j 1. +0.j]

# %%
def create_A(circuit, idx):
    if idx == 0:
        None
    elif idx == 1:
        circuit.cx(0,2)
    elif idx == 2:
        circuit.cx(0,1)
        circuit.cx(0,2)
    elif idx == 3:
        circuit.cy(0,1)
        circuit.cy(0,2)
    else:
        None

def create_A_dagger(circuit, idx):
    create_A(circuit, idx)

# %%
# Specify parameters
from qiskit_aer.noise import NoiseModel

shots = 20000
n_qubit = np.log2(len(b))
n_qubit = int(n_qubit)
backend = Aer.get_backend('qasm_simulator')

# Create the function to evaluate the denominator of the Hadamard Test
def denom_Hadamard(l,lp,part='Re'):
    quantum_circuit = QuantumCircuit(n_qubit+1,1)
    quantum_circuit.h(0)
    
    if part == 'Im':
        quantum_circuit.sdg(0)
    
    create_ansatz(quantum_circuit, [i+1 for i in range(n_qubit)], tot_layers)
    create_A(quantum_circuit,l)
    create_A_dagger(quantum_circuit,lp)

    quantum_circuit.h(0)
    quantum_circuit.measure(0,0)

    job = backend.run(quantum_circuit, shots=shots, memory=False, NoiseModel=None).result()
    result = job.get_counts(quantum_circuit)

    try:
        P0 = result["0"]
        P1 = shots - P0
    except:
        P1 = shots
        P0 = 0
    
    beta_denom = (P0 - P1)/shots
    return beta_denom

# Create the function to evaluate the numerator of the Hadamard Test
def numer_Hadamard(l,lp,j,part="Re"):
    quantum_circuit = QuantumCircuit(n_qubit+1,1)
    quantum_circuit.h(0)

    if part == "Im":
        quantum_circuit.sdg(0)
    
    create_ansatz(quantum_circuit, [i+1 for i in range(n_qubit)], tot_layers)
    create_A(quantum_circuit, l)
    create_b_dagger(quantum_circuit, [i+1 for i in range(n_qubit)])
    quantum_circuit.cz(0,j)
    create_b(quantum_circuit, [i+1 for i in range(n_qubit)])
    create_A_dagger(quantum_circuit, lp)

    quantum_circuit.h(0)
    quantum_circuit.measure(0,0)

    job = backend.run(quantum_circuit, shots=shots, memory=False, NoiseModel=None).result()
    result = job.get_counts(quantum_circuit)

    try:
        P0 = result["0"]
        P1 = shots - P0
    except:
        P1 = shots
        P0 = 0
    
    delta_num = (P0 - P1)/shots
    return delta_num

# Create the function for the classical evaluation of the cost function
def cost_function(ansatz_param_updated):
    global ansatz_param, iteration

    ansatz_param = ansatz_param_updated
    num_sum = 0
    denom_sum = 0
    
    #start = time.time()

    for l in range(len(c)):
        for lp in range(len(c)):
            denom_sum += (c[l] * np.conj(c[lp]) * denom_Hadamard(l,lp,"Re"))
            for j in range(1,n_qubit+1):
                num_sum += (c[l] * np.conj(c[lp]) * numer_Hadamard(l,lp,j,"Re"))
    
    x = 0.5 - 0.5*num_sum/(n_qubit * denom_sum)
    #x = 1 - num_sum*num_sum/denom_sum
    x = abs(x)
    
    #end = time.time()
    
    #print(f'Iteration: {iteration}\tCost Function: {x}\tExecution Time: {end - start}')
    #time_list.append(end - start)
    print(f'Iteration: {iteration}\tCost Function: {x}')
    cost_list.append(x)
    iteration += 1
    return x

# %% [markdown]
# ### Number of layers in Ansatz Needed:
#
# The below tables(?) show the effectiveness if the number of layers:
#
# layers = 1 (not useful) -- > Not enough parameters for search space (cost function minimization is successful but yields incorrect states)
#
# layers = 2 (not good) --> Cost function minimization successful but incorrect solution
#
# layers = 4 (semi-decent approximation --> Not entirely useful) --> Large error but solution somewhat matches but needs more parameters/shots
#
# layers = 6 --> better results than 4 layer ansatz --> Needs a bigger search space
#
# layers = 8 --> better-ish --> not too good
#
# layers = 10 --> Looks a lot better but maybe needs more parameters for better resolution ---> Best Resolution!
#
# layers = 12 --> Stagnant Cost Function --> Definitely not good! --> Not optimization occurs (Try with double shot number).
#
# layers = 16 --> Similar Results to layers = 10 --> Increasing Parameters seems to not increase the resolution (but this was tried with lower number of shots)

# %%
tot_layers = 16
x_num = (sol/np.linalg.norm(sol,2))**2
iteration = 1
cost_list = []
theta0 = [random.random() * 2 * np.pi for i in range(tot_layers * n_qubit)]
minimize(cost_function, x0=theta0, args=(), method='COBYLA', options={'maxiter':500, "rhobeg":np.pi/4})
# Out:
# Iteration: 1	Cost Function: 0.8024595505503569
# Iteration: 2	Cost Function: 0.7286418314372866
# Iteration: 3	Cost Function: 0.9066199862684159
# Iteration: 4	Cost Function: 0.849725525118737
# Iteration: 5	Cost Function: 0.6852980458506969
# Iteration: 6	Cost Function: 0.7408654982858495
# Iteration: 7	Cost Function: 0.7935493394810074
# Iteration: 8	Cost Function: 0.5830781473011059
# Iteration: 9	Cost Function: 0.5067396174506885
# Iteration: 10	Cost Function: 0.5019265107569952
# Iteration: 11	Cost Function: 0.5073380896365377
# Iteration: 12	Cost Function: 0.5078307741394283
# Iteration: 13	Cost Function: 0.510426831961897
# Iteration: 14	Cost Function: 0.5052827367748576
# Iteration: 15	Cost Function: 0.5136065594888443
# Iteration: 16	Cost Function: 0.5546017488758641
# Iteration: 17	Cost Function: 0.5259896737661434
# Iteration: 18	Cost Function: 0.49958396092768464
# Iteration: 19	Cost Function: 0.5211955053392919
# Iteration: 20	Cost Function: 0.5356894030267676
# Iteration: 21	Cost Function: 0.5266588167719701
# Iteration: 22	Cost Function: 0.5014913844325609
# Iteration: 23	Cost Function: 0.5045614590707552
# Iteration: 24	Cost Function: 0.5447062415506894
# Iteration: 25	Cost Function: 0.49570576789549325
# Iteration: 26	Cost Function: 0.5037128296083428
# Iteration: 27	Cost Function: 0.5026272238311957
# Iteration: 28	Cost Function: 0.4902817381979479
# Iteration: 29	Cost Function: 0.4983630208725535
# Iteration: 30	Cost Function: 0.6206984258761863
# Iteration: 31	Cost Function: 0.53598554369746
# Iteration: 32	Cost Function: 0.508405067123561
# Iteration: 33	Cost Function: 0.510354072505211
# Iteration: 34	Cost Function: 0.6878720476862845
# Iteration: 35	Cost Function: 0.48789261926496935
# Iteration: 36	Cost Function: 0.4781950309793163
# Iteration: 37	Cost Function: 0.46628822152325966
# Iteration: 38	Cost Function: 0.5590627073831017
# Iteration: 39	Cost Function: 0.48702134649471307
# Iteration: 40	Cost Function: 0.33908899840556606
# Iteration: 41	Cost Function: 0.2698748991121872
# Iteration: 42	Cost Function: 0.288295256227193
# Iteration: 43	Cost Function: 0.4604098684861066
# Iteration: 44	Cost Function: 0.31114495610105697
# Iteration: 45	Cost Function: 0.562260725143565
# Iteration: 46	Cost Function: 0.4604747714869253
# Iteration: 47	Cost Function: 0.1206624605678237
# Iteration: 48	Cost Function: 0.42501538082933443
# Iteration: 49	Cost Function: 0.301939716649235
# Iteration: 50	Cost Function: 0.6176520789240116
# Iteration: 51	Cost Function: 0.4718802698145024
# Iteration: 52	Cost Function: 0.9841589239412274
# Iteration: 53	Cost Function: 0.38387963743676246
# Iteration: 54	Cost Function: 0.9335991765276914
# Iteration: 55	Cost Function: 0.13675144880875723
# Iteration: 56	Cost Function: 0.5440998247994414
# Iteration: 57	Cost Function: 0.39122189108642524
# Iteration: 58	Cost Function: 0.47327810975685825
# Iteration: 59	Cost Function: 0.35715578071286413
# Iteration: 60	Cost Function: 0.816564674826014
# Iteration: 61	Cost Function: 0.5589647146835125
# Iteration: 62	Cost Function: 0.18581577658010784
# Iteration: 63	Cost Function: 0.3049103263016508
# Iteration: 64	Cost Function: 0.5271364870933938
# Iteration: 65	Cost Function: 0.13753514526710253
# Iteration: 66	Cost Function: 0.48358733880422033
# Iteration: 67	Cost Function: 0.759150505326413
# Iteration: 68	Cost Function: 0.27749901224812346
# Iteration: 69	Cost Function: 0.4229097501310498
# Iteration: 70	Cost Function: 0.18622313611037322
# Iteration: 71	Cost Function: 0.42014470677837
# Iteration: 72	Cost Function: 0.3277355131110394
# Iteration: 73	Cost Function: 0.5806209313970955
# Iteration: 74	Cost Function: 0.18841980543776443
# Iteration: 75	Cost Function: 0.48971305595408865
# Iteration: 76	Cost Function: 0.14013349193761598
# Iteration: 77	Cost Function: 0.668323381734292
# Iteration: 78	Cost Function: 0.16877670517486998
# Iteration: 79	Cost Function: 0.40894936708860785
# Iteration: 80	Cost Function: 0.28932991414873466
# Iteration: 81	Cost Function: 0.1921022510492178
# Iteration: 82	Cost Function: 0.8099221498615166
# Iteration: 83	Cost Function: 0.11590259454705387
# Iteration: 84	Cost Function: 0.30035828025477757
# Iteration: 85	Cost Function: 0.1474753018660817
# Iteration: 86	Cost Function: 0.28524862325882855
# Iteration: 87	Cost Function: 0.3411670198947144
# Iteration: 88	Cost Function: 0.28711696997977904
# Iteration: 89	Cost Function: 0.22603887399463773
# Iteration: 90	Cost Function: 0.25989558037882443
# Iteration: 91	Cost Function: 0.14374908182753182
# Iteration: 92	Cost Function: 0.23279919879819705
# Iteration: 93	Cost Function: 0.3212168202134449
# Iteration: 94	Cost Function: 0.2694268888250503
# Iteration: 95	Cost Function: 0.3017738085439134
# Iteration: 96	Cost Function: 0.2584439359267744
# Iteration: 97	Cost Function: 0.3324557816174212
# Iteration: 98	Cost Function: 0.1299113815929953
# Iteration: 99	Cost Function: 0.3097986021703142
# Iteration: 100	Cost Function: 0.1659814737718575
# Iteration: 101	Cost Function: 0.030810770824086342
# Iteration: 102	Cost Function: 0.06163240790176222
# Iteration: 103	Cost Function: 0.14008853379399666
# Iteration: 104	Cost Function: 0.1144266593072984
# Iteration: 105	Cost Function: 0.14051805522775457
# Iteration: 106	Cost Function: 0.06346232456737888
# Iteration: 107	Cost Function: 0.2565717415115011
# Iteration: 108	Cost Function: 0.11023391812865446
# Iteration: 109	Cost Function: 0.11891441495060162
# Iteration: 110	Cost Function: 0.032456267167845054
# Iteration: 111	Cost Function: 0.1522593320235756
# Iteration: 112	Cost Function: 0.1281991893456872
# Iteration: 113	Cost Function: 0.02544975866608229
# Iteration: 114	Cost Function: 0.11096987415787501
# Iteration: 115	Cost Function: 0.09509360877985751
# Iteration: 116	Cost Function: 0.06615686274509691
# Iteration: 117	Cost Function: 0.08216432865731504
# Iteration: 118	Cost Function: 0.1650365489550087
# Iteration: 119	Cost Function: 0.135294117647058
# Iteration: 120	Cost Function: 0.06944048974943112
# Iteration: 121	Cost Function: 0.14691383036196676
# Iteration: 122	Cost Function: 0.1693850562045407
# Iteration: 123	Cost Function: 0.11151634170290198
# Iteration: 124	Cost Function: 0.23512315270935996
# Iteration: 125	Cost Function: 0.10085862861289141
# Iteration: 126	Cost Function: 0.12037693070709915
# Iteration: 127	Cost Function: 0.098048196166855
# Iteration: 128	Cost Function: 0.06301359629463765
# Iteration: 129	Cost Function: 0.0844308560677327
# Iteration: 130	Cost Function: 0.1254025541365903
# Iteration: 131	Cost Function: 0.051835853131748544
# Iteration: 132	Cost Function: 0.13014410934482268
# Iteration: 133	Cost Function: 0.03648387576163009
# Iteration: 134	Cost Function: 0.0910512664021978
# Iteration: 135	Cost Function: 0.0668694122819864
# Iteration: 136	Cost Function: 0.11456166419019481
# Iteration: 137	Cost Function: 0.06200304517002164
# Iteration: 138	Cost Function: 0.05001549666821692
# Iteration: 139	Cost Function: 0.09507694499857466
# Iteration: 140	Cost Function: 0.05765132139812418
# Iteration: 141	Cost Function: 0.07616881079385035
# Iteration: 142	Cost Function: 0.07051562956470842
# Iteration: 143	Cost Function: 0.12471231300345292
# Iteration: 144	Cost Function: 0.11241235267790373
# Iteration: 145	Cost Function: 0.1395073112896854
# Iteration: 146	Cost Function: 0.014314414866899217
# Iteration: 147	Cost Function: 0.13063934863854748
# Iteration: 148	Cost Function: 0.058094198378041306
# Iteration: 149	Cost Function: 0.05773955773955797
# Iteration: 150	Cost Function: 0.11146932395467024
# Iteration: 151	Cost Function: 0.008777852802159702
# Iteration: 152	Cost Function: 0.05299745851397902
# Iteration: 153	Cost Function: 0.053011487115801004
# Iteration: 154	Cost Function: 0.0779399017624966
# Iteration: 155	Cost Function: 0.06596736596736585
# Iteration: 156	Cost Function: 0.1440426997245175
# Iteration: 157	Cost Function: 0.1084971910112349
# Iteration: 158	Cost Function: 0.04850121728545492
# Iteration: 159	Cost Function: 0.016371077762619313
# Iteration: 160	Cost Function: 0.09900742644958715
# Iteration: 161	Cost Function: 0.05200729927007397
# Iteration: 162	Cost Function: 0.08844877644131122
# Iteration: 163	Cost Function: 0.02507587253414273
# Iteration: 164	Cost Function: 0.04486215538847149
# Iteration: 165	Cost Function: 0.06876649076517216
# Iteration: 166	Cost Function: 0.06549736729756733
# Iteration: 167	Cost Function: 0.11289208235456594
# Iteration: 168	Cost Function: 0.07667671439336837
# Iteration: 169	Cost Function: 0.10188027628549651
# Iteration: 170	Cost Function: 0.1265554492000549
# Iteration: 171	Cost Function: 0.009426847662141746
# Iteration: 172	Cost Function: 0.09726048362412143
# Iteration: 173	Cost Function: 0.060437265004873675
# Iteration: 174	Cost Function: 0.08215560844986575
# Iteration: 175	Cost Function: 0.09148207519673601
# Iteration: 176	Cost Function: 0.10468493496653763
# Iteration: 177	Cost Function: 0.03355848153214769
# Iteration: 178	Cost Function: 0.0411697898921064
# Iteration: 179	Cost Function: 0.04944116733933396
# Iteration: 180	Cost Function: 0.10211473730425813
# Iteration: 181	Cost Function: 0.09566169426577303
# Iteration: 182	Cost Function: 0.03795948987246667
# Iteration: 183	Cost Function: 0.04970426132544886
# Iteration: 184	Cost Function: 0.09078667611622881
# Iteration: 185	Cost Function: 0.08810116086235686
# Iteration: 186	Cost Function: 0.007152692778457537
# Iteration: 187	Cost Function: 0.0890203433847927
# Iteration: 188	Cost Function: 0.0519244226731983
# Iteration: 189	Cost Function: 0.06820539419086996
# Iteration: 190	Cost Function: 0.11653513238289143
# Iteration: 191	Cost Function: 0.07907360215859804
# Iteration: 192	Cost Function: 0.13669786096256686
# Iteration: 193	Cost Function: 0.021875000000000644
# Iteration: 194	Cost Function: 0.08744411326378443
# Iteration: 195	Cost Function: 0.13676140613313426
# Iteration: 196	Cost Function: 0.13885130564199633
# Iteration: 197	Cost Function: 0.06365756162558384
# Iteration: 198	Cost Function: 0.06561928862645716
# Iteration: 199	Cost Function: 0.05035913806863607
# Iteration: 200	Cost Function: 0.03419982573337116
# Iteration: 201	Cost Function: 0.020380434782607204
# Iteration: 202	Cost Function: 0.09872776840192271
# Iteration: 203	Cost Function: 0.06070275821596094
# Iteration: 204	Cost Function: 0.05924479166666513
# Iteration: 205	Cost Function: 0.0166442250149606
# Iteration: 206	Cost Function: 0.09864287509424319
# Iteration: 207	Cost Function: 0.10549132947976941
# Iteration: 208	Cost Function: 0.06285473232091038
# Iteration: 209	Cost Function: 0.03567251461988258
# Iteration: 210	Cost Function: 0.10522749964341915
# Iteration: 211	Cost Function: 0.12855704697986609
# Iteration: 212	Cost Function: 0.08407407407407508
# Iteration: 213	Cost Function: 0.04394864428083978
# Iteration: 214	Cost Function: 0.06042011745219256
# Iteration: 215	Cost Function: 0.0824976496396112
# Iteration: 216	Cost Function: 0.031118526040912087
# Iteration: 217	Cost Function: 0.1273157144707875
# Iteration: 218	Cost Function: 0.09427737596751773
# Iteration: 219	Cost Function: 0.05858722200797095
# Iteration: 220	Cost Function: 0.03517420311341812
# Iteration: 221	Cost Function: 0.005223447475332321
# Iteration: 222	Cost Function: 0.14796176731231797
# Iteration: 223	Cost Function: 0.1124283480979677
# Iteration: 224	Cost Function: 0.07437517750639033
# Iteration: 225	Cost Function: 0.08826371339378364
# Iteration: 226	Cost Function: 0.0699364521362894
# Iteration: 227	Cost Function: 0.05030365990091268
# Iteration: 228	Cost Function: 0.11946997989083485
# Iteration: 229	Cost Function: 0.08085136274234406
# Iteration: 230	Cost Function: 0.12433574056410912
# Iteration: 231	Cost Function: 0.08903603119118092
# Iteration: 232	Cost Function: 0.09124999999999744
# Iteration: 233	Cost Function: 0.04073012520742186
# Iteration: 234	Cost Function: 0.03812857573020095
# Iteration: 235	Cost Function: 0.03655311868097577
# Iteration: 236	Cost Function: 0.07427589233469939
# Iteration: 237	Cost Function: 0.09776874821785114
# Iteration: 238	Cost Function: 0.08648224725509712
# Iteration: 239	Cost Function: 0.03420207329537345
# Iteration: 240	Cost Function: 0.08222317719524386
# Iteration: 241	Cost Function: 0.05889057750759863
# Iteration: 242	Cost Function: 0.013842058562554715
# Iteration: 243	Cost Function: 0.06595877144438417
# Iteration: 244	Cost Function: 0.12691798941799015
# Iteration: 245	Cost Function: 0.11970792152234927
# Iteration: 246	Cost Function: 0.08589498455655215
# Iteration: 247	Cost Function: 0.026848781894191043
# Iteration: 248	Cost Function: 0.026987790351400143
# Iteration: 249	Cost Function: 0.036492687123601264
# Iteration: 250	Cost Function: 0.023590150913422925
# Iteration: 251	Cost Function: 0.11368926389293021
# Iteration: 252	Cost Function: 0.1313045256270436
# Iteration: 253	Cost Function: 0.007698015210535036
# Iteration: 254	Cost Function: 0.12958610784697755
# Iteration: 255	Cost Function: 0.06986899563318721
# Iteration: 256	Cost Function: 0.06288751107174417
# Iteration: 257	Cost Function: 0.05843410378080405
# Iteration: 258	Cost Function: 0.11309357541899545
# Iteration: 259	Cost Function: 0.0416151945645471
# Iteration: 260	Cost Function: 0.05398806294085795
# Iteration: 261	Cost Function: 0.0918401838831791
# Iteration: 262	Cost Function: 0.029129637466497715
# Iteration: 263	Cost Function: 0.15558583106267043
# Iteration: 264	Cost Function: 0.05746404133500976
# Iteration: 265	Cost Function: 0.04160719383385553
# Iteration: 266	Cost Function: 0.06864557655437037
# Iteration: 267	Cost Function: 0.12178151510641427
# Iteration: 268	Cost Function: 0.038455946496073756
# Iteration: 269	Cost Function: 0.002301752301752391
# Iteration: 270	Cost Function: 0.0804433887569298
# Iteration: 271	Cost Function: 0.020255615801703875
# Iteration: 272	Cost Function: 0.06761846069570077
# Iteration: 273	Cost Function: 0.04354570217917764
# Iteration: 274	Cost Function: 0.07207207207207306
# Iteration: 275	Cost Function: 0.11912878787878844
# Iteration: 276	Cost Function: 0.051340539023020604
# Iteration: 277	Cost Function: 0.012617129705739083
# Iteration: 278	Cost Function: 0.0932517482517477
# Iteration: 279	Cost Function: 0.01856320049813065
# Iteration: 280	Cost Function: 0.08932245737801414
# Iteration: 281	Cost Function: 0.12078651685393293
# Iteration: 282	Cost Function: 0.06978055012776152
# Iteration: 283	Cost Function: 0.03318584070796349
# Iteration: 284	Cost Function: 0.07553767483832163
# Iteration: 285	Cost Function: 0.15038535645472095
# Iteration: 286	Cost Function: 0.013180272108844204
# Iteration: 287	Cost Function: 0.012075283144570459
# Iteration: 288	Cost Function: 0.007887042166821345
# Iteration: 289	Cost Function: 0.11520657731104089
# Iteration: 290	Cost Function: 0.0972128492374133
# Iteration: 291	Cost Function: 0.1797306176084108
# Iteration: 292	Cost Function: 0.0189315764407052
# Iteration: 293	Cost Function: 0.08195675026280153
# Iteration: 294	Cost Function: 0.03071621216661735
# Iteration: 295	Cost Function: 0.07824127074985598
# Iteration: 296	Cost Function: 0.04151553382747336
# Iteration: 297	Cost Function: 0.08517661179698421
# Iteration: 298	Cost Function: 0.06523391319034039
# Iteration: 299	Cost Function: 0.08462680523687277
# Iteration: 300	Cost Function: 0.11381308685446079
# Iteration: 301	Cost Function: 0.12315342986690081
# Iteration: 302	Cost Function: 0.06916810841983878
# Iteration: 303	Cost Function: 0.02288919205699541
# Iteration: 304	Cost Function: 0.027769370460049236
#  message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 0.027769370460049236
#        x: [ 2.455e+00  3.438e+00 ...  2.597e+00  5.575e-02]
#     nfev: 304
#    maxcv: 0.0

# %%
plt.plot(cost_list)
plt.xlabel('Iteration Index')
plt.ylabel('Cost Function')
plt.grid()
plt.show()

# %%
#For 4 layers - ansatz_param = [3.454e+00, 6.545e-01, 6.697e+00, 6.953e+00, 3.135e+00, 2.139e+00, 2.349e+00, 5.551e+00]
#ansatz_param = [5.133e+00, 1.648e+00, 4.014e+00, 3.322e+00, 4.505e+00, 3.769e+00, 6.427e+00, 4.317e+00, 6.761e+00, 3.337e+00, 4.421e+00, 5.485e+00]
qc_final = QuantumCircuit(n_qubit)
create_ansatz(qc_final, [0,1], tot_layers, False)
qc_final.measure_all()
job = backend.run(qc_final, shots=100*shots, memory=False).result()
results = job.get_counts(0)
for key in results:
    results[key] *= (0.01/shots)
plot_histogram(results)

# %%
qc_final.draw('mpl')

# %%
np.savetxt('Opt_Params_Poisson_4x4.txt', ansatz_param)

# %%
x_num = (sol/np.linalg.norm(sol,2))**2
print(x_num)
# Out:
# [0.15384615+0.j 0.34615385+0.j 0.34615385+0.j 0.15384615+0.j]

# %%
x_quant = np.zeros(4)
for i in range(4):
    key = bin(i)[2:]
    if len(key) < 2:
        key = '0' * (2 - len(key)) + key
    x_quant[i] = counts[str(key)]
print(f'Error Norm: {np.linalg.norm(x_quant - x_num,2)}\tMax Error:{max(abs(x_quant - x_num))}')
# Out:
# Error Norm: 0.08452992004165456	Max Error:0.062343846153846166

# %%
x_quant
# Out:
# array([0.1511    , 0.35457611, 0.34289278, 0.15143111])

# %% [markdown]
# ## Gradient Based Approach to Minimization

# %%
def cost_function_gradient(ansatz_param_updated, *args):
    global ansatz_param
    params = copy.deepcopy(ansatz_param_updated)
    num_sum = 0
    denom_sum = 0
    gradient = []
    g = 0
    f = 0
    ansatz_param = ansatz_param_updated
    
    for l in range(len(c)):
        for lp in range(len(c)):
            g += (c[l] * np.conj(c[lp]) * denom_Hadamard(l,lp,'Re'))
            for j in range(1,n_qubit+1):
                f += (c[l] * np.conj(c[lp]) * numer_Hadamard(l,lp,j,'Re'))
    
    for i in range(len(params)):
        pos_g = 0
        pos_f = 0
        neg_g = 0
        neg_f = 0
        
        pos_ansatz_param = copy.deepcopy(params)
        pos_ansatz_param[i] = pos_ansatz_param[i] + np.pi/2
        ansatz_param = pos_ansatz_param
        
        for l in range(len(c)):
            for lp in range(len(c)):
                pos_g += (c[l] * np.conj(c[lp]) * denom_Hadamard(l,lp,'Re'))
                for j in range(1,n_qubit+1):
                    pos_f += (c[l] * np.conj(c[lp]) * numer_Hadamard(l,lp,j,'Re'))
        
        neg_ansatz_param = copy.deepcopy(params)
        neg_ansatz_param[i] = neg_ansatz_param[i] - np.pi/2
        ansatz_param = neg_ansatz_param
        
        for l in range(len(c)):
            for lp in range(len(c)):
                neg_g += (c[l] * np.conj(c[lp]) * denom_Hadamard(l,lp,'Re'))
                for j in range(1,n_qubit+1):
                    neg_f += (c[l] * np.conj(c[lp]) * numer_Hadamard(l,lp,j,'Re'))
        
        dg = 0.5 * (pos_g - neg_g)
        df = 0.5 * (pos_f - neg_f)
        dc = -1/(2*n_qubit) * (g * df - f * dg)/(g*g)
        
        if dc < 0:
            dc = -1*abs(dc)
        else:
            dc = abs(dc)
        gradient.append(dc)
    ansatz_param = params
    return gradient

# %%
tot_layers = 8
theta = [random.random() * 2 * np.pi for i in range(tot_layers * n_qubit)]
cost_list = []
time_list = []
iteration = 1
minimize(cost_function, x0=theta, jac=cost_function_gradient, args=(), method='SLSQP', options={'maxiter':500})
# Out:
# Iteration: 1	Cost Function: 0.9575903712108933
# Iteration: 2	Cost Function: 0.8870532703978424
# Iteration: 3	Cost Function: 0.5498260510643316
# Iteration: 4	Cost Function: 0.7115306783228104
# Iteration: 5	Cost Function: 0.4827430887900456
# Iteration: 6	Cost Function: 0.4904252155813262
# Iteration: 7	Cost Function: 0.49148179749715587
# Iteration: 8	Cost Function: 0.49485949280328995
# Iteration: 9	Cost Function: 0.5018175157799819
# Iteration: 10	Cost Function: 0.49955870629768817
# Iteration: 11	Cost Function: 0.49270187219029193
# Iteration: 12	Cost Function: 0.49980163228292906
# Iteration: 13	Cost Function: 0.5020401846015309
# Iteration: 14	Cost Function: 0.49948956442831216
# Iteration: 15	Cost Function: 0.5016329660343065
# Iteration: 16	Cost Function: 0.498372764319674
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.498372764319674
#        x: [ 5.103e+00 -5.733e-01 ...  3.515e+00 -4.607e-01]
#      nit: 4
#      jac: [-6.807e-03 -2.045e-02 ...  2.072e-02 -3.337e-03]
#     nfev: 16
#     njev: 4

# %%
#For 4 layers - ansatz_param = [3.454e+00, 6.545e-01, 6.697e+00, 6.953e+00, 3.135e+00, 2.139e+00, 2.349e+00, 5.551e+00]
#ansatz_param = [5.133e+00, 1.648e+00, 4.014e+00, 3.322e+00, 4.505e+00, 3.769e+00, 6.427e+00, 4.317e+00, 6.761e+00, 3.337e+00, 4.421e+00, 5.485e+00]
qc_final = QuantumCircuit(n_qubit)
create_ansatz(qc_final, [0,1], tot_layers, False)
qc_final.measure_all()
results = execute(qc_final, backend=backend, shots=10*shots, noise_model=noise_model)
counts = results.result().get_counts()
for key in counts:
    counts[key] *= (1/shots)/10
plot_histogram(counts)

# %%
qc_final.draw('mpl')
